# %% [markdown]
# # Getting Started To The Project

# %%
df = pd.read_csv("../data/raw/ecommerce_sales.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("E-Commerce Sales Analytics Project")
# Out:
# E-Commerce Sales Analytics Project

# %% [markdown]
# # DATA UNDERSTANDING

# %%
df.head()
# Out:
#     Order ID  Order Date Customer ID        Category                Product  \
# 0  ORD100001  2025-03-29    CUST2124  Home & Kitchen  Storage Container Set
# 1  ORD100002  2025-01-22    CUST1253           Books   Data Analytics Guide
# 2  ORD100003  2025-09-01    CUST1832  Home & Kitchen          Non-Stick Pan
# 3  ORD100004  2025-09-22    CUST1565     Electronics      Bluetooth Speaker
# 4  ORD100005  2025-02-23    CUST2130     Electronics             Power Bank
#
#   Region     Channel    Payment Method  Quantity  Unit Price  Discount  \
# 0   East     Website  Cash on Delivery         1      949.29      0.10
# 1   West     Website       Credit Card         1      701.57      0.05
# 2  North     Website        Debit Card         5     1229.57      0.00
# 3  South  Mobile App       Credit Card         4     1966.53      0.15
# 4   West     Website  Cash on Delivery         3      933.74      0.05
#
#    Revenue   Profit
# 0   854.36   151.29
# 1   666.49   164.55
# ...

# %%
df.shape
# Out:
# (5008, 13)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer ID', 'Category', 'Product',
#        'Region', 'Channel', 'Payment Method', 'Quantity', 'Unit Price',
#        'Discount', 'Revenue', 'Profit'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        5008 non-null   str
#  1   Order Date      5008 non-null   str
#  2   Customer ID     5003 non-null   str
#  3   Category        5008 non-null   str
#  4   Product         5005 non-null   str
#  5   Region          5003 non-null   str
#  6   Channel         5008 non-null   str
#  7   Payment Method  5003 non-null   str
#  8   Quantity        5008 non-null   int64
#  9   Unit Price      5008 non-null   float64
#  10  Discount        5008 non-null   float64
#  11  Revenue         5008 non-null   float64
#  12  Profit          5008 non-null   float64
# dtypes: float64(4), int64(1), str(8)
# memory usage: 508.8 KB

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Customer ID       5
# Category          0
# Product           3
# Region            5
# Channel           0
# Payment Method    5
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %% [markdown]
# # DATA CLEANING BEGIN

# %% [markdown]
# # -> Removing Duplicates

# %%
df_clean = df.copy()

# %%
df_clean[df_clean.duplicated()]
# Out:
#        Order ID  Order Date Customer ID        Category              Product  \
# 5000  ORD101502  2025-10-29    CUST1932           Books   Python Programming
# 5001  ORD102587  2025-01-16    CUST1887          Beauty              Shampoo
# 5002  ORD102654  2025-05-03    CUST2071  Home & Kitchen            Air Fryer
# 5003  ORD101056  2025-07-29    CUST1676         Fashion       Cotton T-Shirt
# 5004  ORD100706  2025-04-17    CUST1464         Fashion             Backpack
# 5005  ORD100107  2025-05-04    CUST1975     Electronics    Bluetooth Speaker
# 5006  ORD100590  2025-03-08    CUST1396  Home & Kitchen        Mixer Grinder
# 5007  ORD102469  2025-10-27    CUST1417     Electronics  Wireless Headphones
#
#        Region      Channel    Payment Method  Quantity  Unit Price  Discount  \
# 5000    South      Website               UPI         1      629.60       0.1
# 5001  Central   Mobile App       Net Banking         1      459.75       0.0
# ...

# %%
df_clean = df_clean.drop_duplicates()

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # -> Handling Missing Values

# %%
df_clean.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Customer ID       5
# Category          0
# Product           3
# Region            5
# Channel           0
# Payment Method    5
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %%
df_clean[df_clean.isnull().any(axis=1)]
# Out:
#        Order ID  Order Date Customer ID        Category  \
# 445   ORD100446  2025-04-09    CUST1116         Fashion
# 470   ORD100471  2025-12-12    CUST1538         Fashion
# 912   ORD100913  2025-04-03         NaN         Fashion
# 1853  ORD101854  2025-07-20         NaN           Books
# 2165  ORD102166  2025-03-08    CUST1640  Home & Kitchen
# 2193  ORD102194  2025-10-19    CUST1311     Electronics
# 2231  ORD102232  2025-05-27    CUST1886     Electronics
# 2250  ORD102251  2025-12-24         NaN     Electronics
# 2500  ORD102501  2025-08-07         NaN     Electronics
# 2630  ORD102631  2025-05-03    CUST2114     Electronics
# 3271  ORD103272  2025-08-02    CUST1460         Fashion
# 3678  ORD103679  2025-12-21    CUST1625           Books
# 3805  ORD103806  2025-02-07    CUST1413          Beauty
# 3867  ORD103868  2025-09-11    CUST2173     Electronics
# 4195  ORD104196  2025-12-21         NaN          Beauty
# 4472  ORD104473  2025-10-17    CUST1367         Fashion
# ...

# %%
df_clean["Quantity"] = df_clean["Quantity"].fillna(
    df_clean["Quantity"].median()
)

# %% [markdown]
# # ->Handling categorial missing values

# %%
df_clean.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Customer ID       5
# Category          0
# Product           3
# Region            5
# Channel           0
# Payment Method    5
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %%
df_clean["Payment Method"] = df_clean["Payment Method"].fillna(
    df_clean["Payment Method"].mode()[0]
)

# %%
df_clean.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Customer ID       5
# Category          0
# Product           3
# Region            5
# Channel           0
# Payment Method    0
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %% [markdown]
# # ->Converting Order Date to Proper Date

# %%
df_clean["Order Date"] = pd.to_datetime(
    df_clean["Order Date"],
    errors="coerce"
)

# %%
df_clean["Order Date"].isnull().sum()
# Out:
# np.int64(4)

# %%
df_clean.describe()
# Out:
#                        Order Date     Quantity   Unit Price     Discount  \
# count                        4996  5000.000000  5000.000000  5000.000000
# mean   2025-07-03 18:55:20.416333     1.807000  1532.415772     0.094470
# min           2025-01-01 00:00:00     1.000000   359.660000     0.000000
# 25%           2025-04-07 00:00:00     1.000000   720.352500     0.050000
# 50%           2025-07-04 00:00:00     1.000000  1261.455000     0.100000
# 75%           2025-09-28 00:00:00     2.000000  1789.757500     0.150000
# max           2025-12-31 00:00:00     5.000000  5484.590000     0.250000
# std                           NaN     1.039022  1116.973176     0.072794
#
#             Revenue       Profit
# count   5000.000000  5000.000000
# mean    2495.904780   538.917662
# min      287.660000    63.780000
# 25%      975.170000   213.330000
# 50%     1606.200000   376.780000
# 75%     3104.375000   660.130000
# max    25836.300000  5890.450000
# std     2538.958206   516.187969

# %% [markdown]
# # ->Checking Impossible values

# %%
df_clean[df_clean["Quantity"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Customer ID, Category, Product, Region, Channel, Payment Method, Quantity, Unit Price, Discount, Revenue, Profit]
# Index: []

# %%
df_clean[df_clean["Unit Price"] < 0]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Customer ID, Category, Product, Region, Channel, Payment Method, Quantity, Unit Price, Discount, Revenue, Profit]
# Index: []

# %%
df_clean[df_clean["Revenue"] < 0]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Customer ID, Category, Product, Region, Channel, Payment Method, Quantity, Unit Price, Discount, Revenue, Profit]
# Index: []

# %% [markdown]
# # -> Checking the datatypes and coverting to corect format

# %%
df_clean.dtypes
# Out:
# Order ID                     str
# Order Date        datetime64[us]
# Customer ID                  str
# Category                     str
# Product                      str
# Region                       str
# Channel                      str
# Payment Method               str
# Quantity                   int64
# Unit Price               float64
# Discount                 float64
# Revenue                  float64
# Profit                   float64
# dtype: object

# %%
df_clean["Quantity"] = df_clean["Quantity"].astype(int)

# %% [markdown]
# # ->Removeing spaces

# %%
df_clean["Category"] = df_clean["Category"].str.strip()

# %%
df_clean["Product"] = df_clean["Product"].str.strip()

# %%
df_clean["Payment Method"] = df_clean["Payment Method"].str.strip()

# %% [markdown]
# ## CHECKING FOR CLEANED DATA ##

# %%
df_clean.head()
# Out:
#     Order ID Order Date Customer ID        Category                Product  \
# 0  ORD100001 2025-03-29    CUST2124  Home & Kitchen  Storage Container Set
# 1  ORD100002 2025-01-22    CUST1253           Books   Data Analytics Guide
# 2  ORD100003 2025-09-01    CUST1832  Home & Kitchen          Non-Stick Pan
# 3  ORD100004 2025-09-22    CUST1565     Electronics      Bluetooth Speaker
# 4  ORD100005 2025-02-23    CUST2130     Electronics             Power Bank
#
#   Region     Channel    Payment Method  Quantity  Unit Price  Discount  \
# 0   East     Website  Cash on Delivery         1      949.29      0.10
# 1   West     Website       Credit Card         1      701.57      0.05
# 2  North     Website        Debit Card         5     1229.57      0.00
# 3  South  Mobile App       Credit Card         4     1966.53      0.15
# 4   West     Website  Cash on Delivery         3      933.74      0.05
#
#    Revenue   Profit
# 0   854.36   151.29
# 1   666.49   164.55
# 2  6147.85  1002.66
# ...

# %%
df_clean.shape
# Out:
# (5000, 13)

# %%
df_clean.isnull().sum()
# Out:
# Order ID          0
# Order Date        4
# Customer ID       5
# Category          0
# Product           3
# Region            5
# Channel           0
# Payment Method    0
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %% [markdown]
# # Performing Cleaning for columns Order date, customer ID,Product,Region #

# %%
df_clean[["Order Date", "Customer ID", "Product", "Region"]].isnull().sum()
# Out:
# Order Date     4
# Customer ID    5
# Product        3
# Region         5
# dtype: int64

# %%
df_clean[df_clean["Order Date"].isnull()]
# Out:
#        Order ID Order Date Customer ID Category         Product Region  \
# 827   ORD100828        NaT    CUST1322  Fashion     Denim Jeans   East
# 1385  ORD101386        NaT    CUST1531  Fashion  Cotton T-Shirt  North
# 3162  ORD103163        NaT    CUST1355   Beauty       Sunscreen  North
# 3796  ORD103797        NaT    CUST2026  Fashion     Denim Jeans  South
#
#          Channel    Payment Method  Quantity  Unit Price  Discount  Revenue  \
# 827      Website               UPI         3     1633.06      0.00  4899.18
# 1385  Mobile App  Cash on Delivery         2      755.85      0.25  1133.78
# 3162  Mobile App       Credit Card         2      748.87      0.05  1422.85
# 3796     Website               UPI         2     1439.01      0.10  2590.22
#
#        Profit
# 827   1360.96
# 1385   360.56
# 3162   485.73
# 3796   750.24

# %%
# Handle missing Order Date
df_clean = df_clean.dropna(subset=["Order Date"])
# Handle missing Customer ID
df_clean["Customer ID"] = df_clean["Customer ID"].fillna("Unknown")
# Handle missing Product
df_clean["Product"] = df_clean["Product"].fillna("Unknown")
# Handle missing Region
df_clean["Region"] = df_clean["Region"].fillna("Unknown")

# %%
df_clean[["Order Date", "Customer ID", "Product", "Region"]].isnull().sum()
# Out:
# Order Date     0
# Customer ID    0
# Product        0
# Region         0
# dtype: int64

# %%
print("Remaining missing values:")
print(df_clean.isnull().sum())
# Out:
# Remaining missing values:
# Order ID          0
# Order Date        0
# Customer ID       0
# Category          0
# Product           0
# Region            0
# Channel           0
# Payment Method    0
# Quantity          0
# Unit Price        0
# Discount          0
# Revenue           0
# Profit            0
# dtype: int64

# %% [markdown]
# # -> Duplicate checking

# %% [markdown]
# ## Saving cleaned dataset ##

# %%
df_clean.to_csv('ecommerce_sales_cleaned.csv', index=False)

# %%
import os

print(os.path.exists('ecommerce_sales_cleaned.csv'))
# Out:
# True

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Performing Exploratory Data Analysis(EDA) ##

# %%
import pandas as pd

df_clean = pd.read_csv('ecommerce_sales_cleaned.csv')

# %%
df_clean['Order Date'] = pd.to_datetime(df_clean['Order Date'], errors='coerce')

# %%
df_clean.shape
# Out:
# (4996, 13)

# %%
df_clean.head()
# Out:
#     Order ID Order Date Customer ID        Category                Product  \
# 0  ORD100001 2025-03-29    CUST2124  Home & Kitchen  Storage Container Set
# 1  ORD100002 2025-01-22    CUST1253           Books   Data Analytics Guide
# 2  ORD100003 2025-09-01    CUST1832  Home & Kitchen          Non-Stick Pan
# 3  ORD100004 2025-09-22    CUST1565     Electronics      Bluetooth Speaker
# 4  ORD100005 2025-02-23    CUST2130     Electronics             Power Bank
#
#   Region     Channel    Payment Method  Quantity  Unit Price  Discount  \
# 0   East     Website  Cash on Delivery         1      949.29      0.10
# 1   West     Website       Credit Card         1      701.57      0.05
# 2  North     Website        Debit Card         5     1229.57      0.00
# 3  South  Mobile App       Credit Card         4     1966.53      0.15
# 4   West     Website  Cash on Delivery         3      933.74      0.05
#
#    Revenue   Profit
# 0   854.36   151.29
# 1   666.49   164.55
# 2  6147.85  1002.66
# ...

# %%
df_clean.tail()
# Out:
#        Order ID Order Date Customer ID        Category          Product  \
# 4991  ORD104996 2025-02-12    CUST1423     Electronics        USB-C Hub
# 4992  ORD104997 2025-06-08    CUST1465           Books    Fiction Novel
# 4993  ORD104998 2025-08-23    CUST2195          Beauty          Perfume
# 4994  ORD104999 2025-07-28    CUST1718  Home & Kitchen  Electric Kettle
# 4995  ORD105000 2025-05-24    CUST1838         Fashion   Cotton T-Shirt
#
#        Region     Channel Payment Method  Quantity  Unit Price  Discount  \
# 4991  Central     Website            UPI         2     1222.91      0.05
# 4992     East     Website    Credit Card         1      433.81      0.20
# 4993     East  Mobile App            UPI         1     1417.23      0.15
# 4994     East     Website    Credit Card         1     1499.59      0.15
# 4995     West     Website    Net Banking         3      750.56      0.05
#
#       Revenue  Profit
# 4991  2323.53  410.98
# 4992   347.05   87.25
# 4993  1204.65  403.40
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        4996 non-null   str
#  1   Order Date      4996 non-null   datetime64[us]
#  2   Customer ID     4996 non-null   str
#  3   Category        4996 non-null   str
#  4   Product         4996 non-null   str
#  5   Region          4996 non-null   str
#  6   Channel         4996 non-null   str
#  7   Payment Method  4996 non-null   str
#  8   Quantity        4996 non-null   int64
#  9   Unit Price      4996 non-null   float64
#  10  Discount        4996 non-null   float64
#  11  Revenue         4996 non-null   float64
#  12  Profit          4996 non-null   float64
# dtypes: datetime64[us](1), float64(4), int64(1), str(7)
# memory usage: 507.5 KB

# %%
df_clean.describe()
# Out:
#                        Order Date     Quantity   Unit Price     Discount  \
# count                        4996  4996.000000  4996.000000  4996.000000
# mean   2025-07-03 18:55:20.416333     1.806645  1532.726595     0.094466
# min           2025-01-01 00:00:00     1.000000   359.660000     0.000000
# 25%           2025-04-07 00:00:00     1.000000   720.102500     0.050000
# 50%           2025-07-04 00:00:00     1.000000  1261.455000     0.100000
# 75%           2025-09-28 00:00:00     2.000000  1790.150000     0.150000
# max           2025-12-31 00:00:00     5.000000  5484.590000     0.250000
# std                           NaN     1.039290  1117.309565     0.072775
#
#             Revenue       Profit
# count   4996.000000  4996.000000
# mean    2495.892288   538.757170
# min      287.660000    63.780000
# 25%      974.072500   213.297500
# 50%     1606.200000   376.625000
# 75%     3104.375000   660.057500
# max    25836.300000  5890.450000
# std     2539.628108   516.248201

# %% [markdown]
# # -> Checking Unique Values

# %%
print("Products:", df_clean['Product'].nunique())
print("Customers:", df_clean['Customer ID'].nunique())
print("Regions:", df_clean['Region'].nunique())
# Out:
# Products: 26
# Customers: 1186
# Regions: 7

# %%
print(df_clean['Region'].unique())
# Out:
# <StringArray>
# ['East', 'West', 'North', 'South', 'Central', 'Unknown', 'south']
# Length: 7, dtype: str

# %%
print(df_clean['Product'].unique())
# Out:
# <StringArray>
# [  'Storage Container Set',    'Data Analytics Guide',
#            'Non-Stick Pan',       'Bluetooth Speaker',
#               'Power Bank',             'Moisturizer',
#          'Electric Kettle',                 'Shampoo',
#            'Running Shoes',            'Casual Shirt',
#           'Cotton T-Shirt',               'Sunscreen',
#                  'Perfume',             'Denim Jeans',
#      'Business Management',           'Mixer Grinder',
#       'Python Programming',               'USB-C Hub',
#  'Machine Learning Basics',           'Fiction Novel',
#                'Face Wash',     'Wireless Headphones',
#              'Smart Watch',                'Backpack',
#                'Air Fryer',                 'Unknown']
# Length: 26, dtype: str

# %%
df_clean.select_dtypes(include='number').columns
# Out:
# Index(['Quantity', 'Unit Price', 'Discount', 'Revenue', 'Profit'], dtype='str')

# %%
df_clean.select_dtypes(include='number').describe()
# Out:
#           Quantity   Unit Price     Discount       Revenue       Profit
# count  4996.000000  4996.000000  4996.000000   4996.000000  4996.000000
# mean      1.806645  1532.726595     0.094466   2495.892288   538.757170
# std       1.039290  1117.309565     0.072775   2539.628108   516.248201
# min       1.000000   359.660000     0.000000    287.660000    63.780000
# 25%       1.000000   720.102500     0.050000    974.072500   213.297500
# 50%       1.000000  1261.455000     0.100000   1606.200000   376.625000
# 75%       2.000000  1790.150000     0.150000   3104.375000   660.057500
# max       5.000000  5484.590000     0.250000  25836.300000  5890.450000

# %%
print(df_clean.columns.tolist())
# Out:
# ['Order ID', 'Order Date', 'Customer ID', 'Category', 'Product', 'Region', 'Channel', 'Payment Method', 'Quantity', 'Unit Price', 'Discount', 'Revenue', 'Profit']

# %%
df_clean['Revenue'] = df_clean['Quantity'] * df_clean['Unit Price']

# %%
df_clean[['Quantity', 'Unit Price', 'Revenue']].head()
# Out:
#    Quantity  Unit Price  Revenue
# 0         1      949.29   949.29
# 1         1      701.57   701.57
# 2         5     1229.57  6147.85
# 3         4     1966.53  7866.12
# 4         3      933.74  2801.22

# %% [markdown]
# # OverAll Sales Performance

# %%
total_revenue = df_clean['Revenue'].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 13779611.549999999

# %%
average_order_value = df_clean['Revenue'].mean()

print("Average Order Value:", average_order_value)
# Out:
# Average Order Value: 2758.12881305044

# %%
total_quantity = df_clean['Quantity'].sum()

print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 9026

# %%
total_orders = df_clean.shape[0]

print("Total Orders:", total_orders)
# Out:
# Total Orders: 4996

# %% [markdown]
# # Sales by Product

# %%
product_sales = (
    df_clean.groupby('Product')['Revenue']
    .sum()
    .sort_values(ascending=False)
)

print(product_sales)
# Out:
# Product
# Air Fryer                  1900424.25
# Smart Watch                1401896.55
# Mixer Grinder              1286851.96
# Running Shoes              1021838.40
# Wireless Headphones        1001235.78
# Bluetooth Speaker           852973.31
# Electric Kettle             616882.87
# Denim Jeans                 610971.00
# USB-C Hub                   591084.87
# Backpack                    550211.50
# Casual Shirt                498769.06
# Non-Stick Pan               486692.97
# Power Bank                  437686.93
# Perfume                     356939.70
# Storage Container Set       326163.07
# Cotton T-Shirt              301416.38
# Machine Learning Basics     276590.53
# Data Analytics Guide        222232.76
# Sunscreen                   174545.80
# Python Programming          167998.95
# Business Management         167354.21
# Moisturizer                 151127.93
# Fiction Novel               138120.60
# Shampoo                     125353.83
# ...

# %%
print(product_sales.head(10))
# Out:
# Product
# Air Fryer              1900424.25
# Smart Watch            1401896.55
# Mixer Grinder          1286851.96
# Running Shoes          1021838.40
# Wireless Headphones    1001235.78
# Bluetooth Speaker       852973.31
# Electric Kettle         616882.87
# Denim Jeans             610971.00
# USB-C Hub               591084.87
# Backpack                550211.50
# Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

product_sales.head(10).plot(kind='bar', figsize=(10,6))

plt.title('Top 10 Products by Revenue')
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sales By Region

# %%
region_sales = (
    df_clean.groupby('Region')['Revenue']
    .sum()
    .sort_values(ascending=False)
)

print(region_sales)
# Out:
# Region
# Central    2873515.20
# North      2831987.77
# East       2819283.95
# South      2649859.03
# West       2581423.60
# Unknown      18133.34
# south         5408.66
# Name: Revenue, dtype: float64

# %%
region_sales.plot(kind='bar', figsize=(8,5))

plt.title('Revenue by Region')
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly Sales Analysis

# %%
df_clean['Month'] = df_clean['Order Date'].dt.to_period('M')

# %%
monthly_sales = (
    df_clean.groupby('Month')['Revenue']
    .sum()
)

print(monthly_sales)
# Out:
# Month
# 2025-01    1072107.24
# 2025-02     938781.30
# 2025-03    1138634.35
# 2025-04    1286218.80
# 2025-05    1086036.28
# 2025-06    1274579.89
# 2025-07    1107955.99
# 2025-08    1358491.54
# 2025-09    1229655.54
# 2025-10    1043459.29
# 2025-11    1061407.30
# 2025-12    1182284.03
# Freq: M, Name: Revenue, dtype: float64

# %%
monthly_sales.plot(kind='line', marker='o', figsize=(10,6))

plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top Customers ##

# %%
customer_sales = (
    df_clean.groupby('Customer ID')['Revenue']
    .sum()
    .sort_values(ascending=False)
)

# %%
print(customer_sales.head(10))
# Out:
# Customer ID
# CUST1345    75181.25
# CUST1940    55333.89
# CUST1368    44073.49
# CUST1314    42933.11
# CUST1568    42197.72
# CUST1360    41872.30
# CUST1388    40655.64
# CUST1934    40133.62
# CUST2076    39932.72
# CUST2059    38042.22
# Name: Revenue, dtype: float64

# %%
customer_sales.head(10).plot(kind='bar', figsize=(10,6))

plt.title('Top 10 Customers by Revenue')
plt.xlabel('Customer ID')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
#  # Quantity by Product

# %%
product_quantity = (
    df_clean.groupby('Product')['Quantity']
    .sum()
    .sort_values(ascending=False)
)

print(product_quantity.head(10))
# Out:
# Product
# Bluetooth Speaker      475
# USB-C Hub              456
# Running Shoes          441
# Power Bank             435
# Cotton T-Shirt         432
# Smart Watch            426
# Casual Shirt           414
# Denim Jeans            407
# Wireless Headphones    401
# Backpack               393
# Name: Quantity, dtype: int64

# %%
product_quantity.head(10).plot(kind='bar', figsize=(10,6))

plt.title('Top 10 Products by Quantity Sold')
plt.xlabel('Product')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Saving The EDA dataset

# %%
df_clean.to_csv('ecommerce_sales_eda.csv', index=False)

# %% [markdown]
# ## Customer Analysis ##
# Who are our highest-spending customers?
# Which customers placed the most orders?
# Which customers generated the most profit?
# Who are the most valuable customers overall?

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer ID', 'Category', 'Product',
#        'Region', 'Channel', 'Payment Method', 'Quantity', 'Unit Price',
#        'Discount', 'Revenue', 'Profit'],
#       dtype='str')

# %%
customer_sales = df.groupby("Customer ID")["Revenue"].sum().reset_index()

customer_sales = customer_sales.sort_values(
    by="Revenue",
    ascending=False
)

customer_sales.head(10)
# Out:
#      Customer ID   Revenue
# 340     CUST1345  66963.45
# 928     CUST1940  51586.11
# 362     CUST1368  42349.03
# 309     CUST1314  38677.15
# 382     CUST1388  37662.23
# 1061    CUST2076  37586.11
# 922     CUST1934  37113.80
# 560     CUST1568  36220.48
# 1044    CUST2059  35124.79
# 839     CUST1850  34627.03

# %%
top_10_customers = customer_sales.head(10)

top_10_customers
# Out:
#      Customer ID   Revenue
# 340     CUST1345  66963.45
# 928     CUST1940  51586.11
# 362     CUST1368  42349.03
# 309     CUST1314  38677.15
# 382     CUST1388  37662.23
# 1061    CUST2076  37586.11
# 922     CUST1934  37113.80
# 560     CUST1568  36220.48
# 1044    CUST2059  35124.79
# 839     CUST1850  34627.03

# %%
print("Top 10 Customers by Sales")
print(top_10_customers)
# Out:
# Top 10 Customers by Sales
#      Customer ID   Revenue
# 340     CUST1345  66963.45
# 928     CUST1940  51586.11
# 362     CUST1368  42349.03
# 309     CUST1314  38677.15
# 382     CUST1388  37662.23
# 1061    CUST2076  37586.11
# 922     CUST1934  37113.80
# 560     CUST1568  36220.48
# 1044    CUST2059  35124.79
# 839     CUST1850  34627.03

# %% [markdown]
# # ->Calculate no.of orders per customer

# %%
customer_orders = df.groupby("Customer ID")["Order ID"].nunique().reset_index()

customer_orders = customer_orders.rename(
    columns={"Order ID": "Total Orders"}
)

customer_orders = customer_orders.sort_values(
    by="Total Orders",
    ascending=False
)

customer_orders.head(10)
# Out:
#      Customer ID  Total Orders
# 972     CUST1985            12
# 692     CUST1702            12
# 340     CUST1345            12
# 922     CUST1934            11
# 339     CUST1344            11
# 384     CUST1390            11
# 1061    CUST2076            11
# 785     CUST1796            11
# 218     CUST1221            11
# 1132    CUST2148            10

# %% [markdown]
# # ->Calculate Total Profit per Customers

# %%
customer_profit = df.groupby("Customer ID")["Profit"].sum().reset_index()

customer_profit = customer_profit.sort_values(
    by="Profit",
    ascending=False
)

customer_profit.head(10)
# Out:
#      Customer ID    Profit
# 928     CUST1940  12652.49
# 340     CUST1345  11345.64
# 362     CUST1368   8681.01
# 309     CUST1314   8196.93
# 414     CUST1420   8036.31
# 839     CUST1850   7936.96
# 382     CUST1388   7922.83
# 922     CUST1934   7809.46
# 560     CUST1568   7739.30
# 1044    CUST2059   7248.43

# %%
customer_analysis = df.groupby("Customer ID").agg(
    Total_Sales=("Revenue", "sum"),
    Total_Orders=("Order ID", "nunique"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum")
).reset_index()

customer_analysis.head()
# Out:
#   Customer ID  Total_Sales  Total_Orders  Total_Profit  Total_Quantity
# 0    CUST1001      9289.91             4       1835.71               5
# 1    CUST1002      6436.66             5       1491.26               7
# 2    CUST1003     25008.77             9       4855.44              12
# 3    CUST1004      9026.36             6       1823.69              11
# 4    CUST1005      9130.53             3       2275.23               4

# %% [markdown]
# # ->Top10 Customers By Revenue

# %%
top_customers = customer_analysis.sort_values(
    by="Total_Sales",
    ascending=False
).head(10)

top_customers
# Out:
#      Customer ID  Total_Sales  Total_Orders  Total_Profit  Total_Quantity
# 340     CUST1345     66963.45            12      11345.64              33
# 928     CUST1940     51586.11             9      12652.49              21
# 362     CUST1368     42349.03             8       8681.01              16
# 309     CUST1314     38677.15             8       8196.93              23
# 382     CUST1388     37662.23             8       7922.83              15
# 1061    CUST2076     37586.11            11       6985.51              17
# 922     CUST1934     37113.80            11       7809.46              21
# 560     CUST1568     36220.48             7       7739.30              14
# 1044    CUST2059     35124.79             6       7248.43              16
# 839     CUST1850     34627.03            10       7936.96              21

# %% [markdown]
# # -> Top10 most frequent Customers

# %%
frequent_customers = customer_analysis.sort_values(
    by="Total_Orders",
    ascending=False
).head(10)

frequent_customers
# Out:
#      Customer ID  Total_Sales  Total_Orders  Total_Profit  Total_Quantity
# 972     CUST1985     33159.03            12       6273.02              25
# 692     CUST1702     18209.03            12       4374.25              14
# 340     CUST1345     66963.45            12      11345.64              33
# 922     CUST1934     37113.80            11       7809.46              21
# 339     CUST1344     29571.58            11       6738.68              20
# 384     CUST1390     31040.33            11       4803.19              21
# 1061    CUST2076     37586.11            11       6985.51              17
# 785     CUST1796     29433.36            11       5301.81              21
# 218     CUST1221     34387.23            11       7103.41              23
# 1132    CUST2148     24124.31            10       5361.14              16

# %% [markdown]
# # ->Top 10 Most Profitable Customers

# %%
profitable_customers = customer_analysis.sort_values(
    by="Total_Profit",
    ascending=False
).head(10)

profitable_customers
# Out:
#      Customer ID  Total_Sales  Total_Orders  Total_Profit  Total_Quantity
# 928     CUST1940     51586.11             9      12652.49              21
# 340     CUST1345     66963.45            12      11345.64              33
# 362     CUST1368     42349.03             8       8681.01              16
# 309     CUST1314     38677.15             8       8196.93              23
# 414     CUST1420     33848.96             9       8036.31              19
# 839     CUST1850     34627.03            10       7936.96              21
# 382     CUST1388     37662.23             8       7922.83              15
# 922     CUST1934     37113.80            11       7809.46              21
# 560     CUST1568     36220.48             7       7739.30              14
# 1044    CUST2059     35124.79             6       7248.43              16

# %% [markdown]
# # Creating Customer Value category

# %%
high_value = customer_analysis["Total_Sales"].quantile(0.75)
low_value = customer_analysis["Total_Sales"].quantile(0.25)

print("High Value Threshold:", high_value)
print("Low Value Threshold:", low_value)
# Out:
# High Value Threshold: 14272.28
# Low Value Threshold: 5059.030000000001

# %%
def customer_segment(sales):
    if sales >= high_value:
        return "High Value"
    elif sales >= low_value:
        return "Medium Value"
    else:
        return "Low Value"

customer_analysis["Customer Segment"] = customer_analysis["Total_Sales"].apply(
    customer_segment
)

# %%
customer_analysis.head(10)
# Out:
#   Customer ID  Total_Sales  Total_Orders  Total_Profit  Total_Quantity  \
# 0    CUST1001      9289.91             4       1835.71               5
# 1    CUST1002      6436.66             5       1491.26               7
# 2    CUST1003     25008.77             9       4855.44              12
# 3    CUST1004      9026.36             6       1823.69              11
# 4    CUST1005      9130.53             3       2275.23               4
# 5    CUST1006     20871.97             6       3912.17              14
# 6    CUST1007      1876.05             1        472.00               4
# 7    CUST1008     13527.52             3       2156.48               6
# 8    CUST1009     15552.66             4       2766.99               7
# 9    CUST1010     18166.67             8       3891.21              17
#
#   Customer Segment
# 0     Medium Value
# 1     Medium Value
# 2       High Value
# 3     Medium Value
# 4     Medium Value
# 5       High Value
# 6        Low Value
# 7     Medium Value
# ...

# %% [markdown]
# # ->Analyze the customer segments

# %%
customer_analysis["Customer Segment"].value_counts()
# Out:
# Customer Segment
# Medium Value    592
# High Value      297
# Low Value       296
# Name: count, dtype: int64

# %% [markdown]
# # -> Visualise Top 10 Customers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10 = customer_analysis.sort_values(
    by="Total_Sales",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_10,
    x="Total_Sales",
    y="Customer ID"
)

plt.title("Top 10 Customers by Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Customer ID")

plt.tight_layout()
plt.show()

# %%
customer_analysis.to_csv(
    "../data/processed/customer_analysis.csv",
    index=False
)

# %% [markdown]
# # Product Analysis:
# Which products sell the most?
# Which products generate the most revenue?
# Which products are the most profitable?
# Which categories perform best?
# Which products may need attention?

# %% [markdown]
# # ->Best selling product

# %%
best_selling_products = (
    df.groupby("Product")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

print(best_selling_products.head(10))
# Out:
# Product
# Bluetooth Speaker      478
# USB-C Hub              456
# Running Shoes          441
# Cotton T-Shirt         435
# Power Bank             435
# Smart Watch            426
# Casual Shirt           414
# Denim Jeans            412
# Wireless Headphones    403
# Backpack               394
# Name: Quantity, dtype: int64

# %% [markdown]
# # -> product with highest revenue

# %%
product_revenue = (
    df.groupby("Product")["Revenue"]
      .sum()
      .sort_values(ascending=False)
)

print(product_revenue.head(10))
# Out:
# Product
# Air Fryer              1716837.26
# Smart Watch            1276183.74
# Mixer Grinder          1168745.05
# Running Shoes           925600.89
# Wireless Headphones     911773.39
# Bluetooth Speaker       777281.18
# Denim Jeans             565339.48
# Electric Kettle         554894.77
# USB-C Hub               533095.07
# Backpack                500542.32
# Name: Revenue, dtype: float64

# %% [markdown]
# # ->Most profitable products

# %%
product_profit = (
    df.groupby("Product")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print(product_profit.head(10))
# Out:
# Product
# Air Fryer              349118.76
# Running Shoes          257331.44
# Mixer Grinder          232903.88
# Smart Watch            200464.07
# Denim Jeans            157105.46
# Wireless Headphones    145482.37
# Backpack               139870.44
# Casual Shirt           125468.53
# Bluetooth Speaker      123046.69
# Electric Kettle        110360.57
# Name: Profit, dtype: float64

# %% [markdown]
# # Product Performance Table

# %%
product_analysis = df.groupby("Product").agg(
    Total_Quantity=("Quantity", "sum"),
    Total_Sales=("Revenue", "sum"),
    Total_Profit=("Profit", "sum"),
    Number_of_Orders=("Order ID", "nunique")
)

product_analysis = product_analysis.sort_values(
    "Total_Sales",
    ascending=False
)

print(product_analysis.head(10))
# Out:
#                      Total_Quantity  Total_Sales  Total_Profit  \
# Product
# Air Fryer                       380   1716837.26     349118.76
# Smart Watch                     426   1276183.74     200464.07
# Mixer Grinder                   372   1168745.05     232903.88
# Running Shoes                   441    925600.89     257331.44
# Wireless Headphones             403    911773.39     145482.37
# Bluetooth Speaker               478    777281.18     123046.69
# Denim Jeans                     412    565339.48     157105.46
# Electric Kettle                 386    554894.77     110360.57
# USB-C Hub                       456    533095.07      85365.92
# Backpack                        394    500542.32     139870.44
#
#                      Number_of_Orders
# Product
# Air Fryer                         213
# Smart Watch                       233
# Mixer Grinder                     216
# Running Shoes                     243
# Wireless Headphones               219
# ...

# %% [markdown]
# # ->Calculate profit margin by product

# %%
product_analysis["Profit_Margin"] = (
    product_analysis["Total_Profit"] /
    product_analysis["Total_Sales"]
) * 100
print(product_analysis.head(10))
# Out:
#                      Total_Quantity  Total_Sales  Total_Profit  \
# Product
# Air Fryer                       380   1716837.26     349118.76
# Smart Watch                     426   1276183.74     200464.07
# Mixer Grinder                   372   1168745.05     232903.88
# Running Shoes                   441    925600.89     257331.44
# Wireless Headphones             403    911773.39     145482.37
# Bluetooth Speaker               478    777281.18     123046.69
# Denim Jeans                     412    565339.48     157105.46
# Electric Kettle                 386    554894.77     110360.57
# USB-C Hub                       456    533095.07      85365.92
# Backpack                        394    500542.32     139870.44
#
#                      Number_of_Orders  Profit_Margin
# Product
# Air Fryer                         213      20.334994
# Smart Watch                       233      15.708088
# Mixer Grinder                     216      19.927689
# ...

# %% [markdown]
# # ->Most profitable products by margin

# %%
highest_margin_products = product_analysis.sort_values(
    "Profit_Margin",
    ascending=False
)

print(
    highest_margin_products[
        ["Total_Sales", "Total_Profit", "Profit_Margin"]
    ].head(10)
)
# Out:
#                 Total_Sales  Total_Profit  Profit_Margin
# Product
# Shampoo           115597.12      37507.64      32.446864
# Moisturizer       136247.98      43944.31      32.253183
# Face Wash         100143.59      32001.63      31.955745
# Sunscreen         159459.29      50775.29      31.842165
# Perfume           325458.79     102963.79      31.636506
# Backpack          500542.32     139870.44      27.943779
# Cotton T-Shirt    272283.99      75920.82      27.882954
# Running Shoes     925600.89     257331.44      27.801555
# Denim Jeans       565339.48     157105.46      27.789579
# Casual Shirt      452104.90     125468.53      27.752084

# %% [markdown]
# # ->Analyze product categories

# %%
category_analysis = df.groupby("Category").agg(
    Total_Quantity=("Quantity", "sum"),
    Total_Sales=("Revenue", "sum"),
    Total_Profit=("Profit", "sum"),
    Number_of_Orders=("Order ID", "nunique")
)

category_analysis["Profit_Margin"] = (
    category_analysis["Total_Profit"] /
    category_analysis["Total_Sales"]
) * 100

print(category_analysis)
# Out:
#                 Total_Quantity  Total_Sales  Total_Profit  Number_of_Orders  \
# Category
# Beauty                    1306    836906.77     267192.66               735
# Books                     1572    878272.24     219489.82               870
# Electronics               2199   3898539.10     618247.55              1196
# Fashion                   2099   2717832.34     756229.40              1147
# Home & Kitchen            1872   4174742.71     838644.32              1052
#
#                 Profit_Margin
# Category
# Beauty              31.926216
# Books               24.991092
# Electronics         15.858442
# Fashion             27.824726
# Home & Kitchen      20.088527

# %% [markdown]
# # ->The best category of the products

# %%
best_sales_category = category_analysis.sort_values(
    "Total_Sales",
    ascending=False
)

print(best_sales_category)
# Out:
#                 Total_Quantity  Total_Sales  Total_Profit  Number_of_Orders  \
# Category
# Home & Kitchen            1872   4174742.71     838644.32              1052
# Electronics               2199   3898539.10     618247.55              1196
# Fashion                   2099   2717832.34     756229.40              1147
# Books                     1572    878272.24     219489.82               870
# Beauty                    1306    836906.77     267192.66               735
#
#                 Profit_Margin
# Category
# Home & Kitchen      20.088527
# Electronics         15.858442
# Fashion             27.824726
# Books               24.991092
# Beauty              31.926216

# %%
best_profit_category = category_analysis.sort_values(
    "Total_Profit",
    ascending=False
)

print(best_profit_category)
# Out:
#                 Total_Quantity  Total_Sales  Total_Profit  Number_of_Orders  \
# Category
# Home & Kitchen            1872   4174742.71     838644.32              1052
# Fashion                   2099   2717832.34     756229.40              1147
# Electronics               2199   3898539.10     618247.55              1196
# Beauty                    1306    836906.77     267192.66               735
# Books                     1572    878272.24     219489.82               870
#
#                 Profit_Margin
# Category
# Home & Kitchen      20.088527
# Fashion             27.824726
# Electronics         15.858442
# Beauty              31.926216
# Books               24.991092

# %%
best_margin_category = category_analysis.sort_values(
    "Profit_Margin",
    ascending=False
)

print(best_margin_category)
# Out:
#                 Total_Quantity  Total_Sales  Total_Profit  Number_of_Orders  \
# Category
# Beauty                    1306    836906.77     267192.66               735
# Fashion                   2099   2717832.34     756229.40              1147
# Books                     1572    878272.24     219489.82               870
# Home & Kitchen            1872   4174742.71     838644.32              1052
# Electronics               2199   3898539.10     618247.55              1196
#
#                 Profit_Margin
# Category
# Beauty              31.926216
# Fashion             27.824726
# Books               24.991092
# Home & Kitchen      20.088527
# Electronics         15.858442

# %% [markdown]
# # Create A Performance Chart

# %%
import matplotlib.pyplot as plt

top_products = (
    product_analysis
    .sort_values("Total_Sales", ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))

plt.bar(
    top_products.index,
    top_products["Total_Sales"]
)

plt.title("Top 10 Products by Revenue")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Top 10 products by profit

# %%
top_profit_products = (
    product_analysis
    .sort_values("Total_Profit", ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))

plt.bar(
    top_profit_products.index,
    top_profit_products["Total_Profit"]
)

plt.title("Top 10 Products by Profit")
plt.xlabel("Product")
plt.ylabel("Total Profit")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Categorical Sales Visualization

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    category_analysis.index,
    category_analysis["Total_Sales"]
)

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Categorical Profit Visualization

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    category_analysis.index,
    category_analysis["Total_Profit"]
)

plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Identifying Products Needing Attention

# %%
average_margin = product_analysis["Profit_Margin"].mean()

print("Average Profit Margin:", average_margin)
low_margin_products = product_analysis[
    product_analysis["Profit_Margin"] < average_margin
]

print(
    low_margin_products.sort_values(
        "Total_Sales",
        ascending=False
    ).head(10)
)
# Out:
# Average Profit Margin: 24.146625753510815
#                        Total_Quantity  Total_Sales  Total_Profit  \
# Product
# Air Fryer                         380   1716837.26     349118.76
# Smart Watch                       426   1276183.74     200464.07
# Mixer Grinder                     372   1168745.05     232903.88
# Wireless Headphones               403    911773.39     145482.37
# Bluetooth Speaker                 478    777281.18     123046.69
# Electric Kettle                   386    554894.77     110360.57
# USB-C Hub                         456    533095.07      85365.92
# Non-Stick Pan                     373    440928.58      88046.46
# Power Bank                        435    399174.43      63726.05
# Storage Container Set             361    293337.05      58214.65
#
#                        Number_of_Orders  Profit_Margin
# Product
# Air Fryer                           213      20.334994
# Smart Watch                         233      15.708088
# ...

# %% [markdown]
# # finding product with high sales and high profit

# %%
high_sales = product_analysis["Total_Sales"].median()
high_profit = product_analysis["Total_Profit"].median()

star_products = product_analysis[
    (product_analysis["Total_Sales"] > high_sales) &
    (product_analysis["Total_Profit"] > high_profit)
]

print(star_products.sort_values(
    "Total_Profit",
    ascending=False
))
# Out:
#                      Total_Quantity  Total_Sales  Total_Profit  \
# Product
# Air Fryer                       380   1716837.26     349118.76
# Running Shoes                   441    925600.89     257331.44
# Mixer Grinder                   372   1168745.05     232903.88
# Smart Watch                     426   1276183.74     200464.07
# Denim Jeans                     412    565339.48     157105.46
# Wireless Headphones             403    911773.39     145482.37
# Backpack                        394    500542.32     139870.44
# Casual Shirt                    414    452104.90     125468.53
# Bluetooth Speaker               478    777281.18     123046.69
# Electric Kettle                 386    554894.77     110360.57
# Non-Stick Pan                   373    440928.58      88046.46
#
#                      Number_of_Orders  Profit_Margin
# Product
# Air Fryer                         213      20.334994
# Running Shoes                     243      27.801555
# ...

# %%
product_analysis.to_csv(
    "product_analysis.csv"
)

category_analysis.to_csv(
    "category_analysis.csv"
)

# %% [markdown]
# ## RegionalAnalysis ##

# %%
print(df["Region"].unique())
print(df["Region"].value_counts())
# Out:
# <StringArray>
# ['East', 'West', 'North', 'South', 'Central', nan, 'south']
# Length: 7, dtype: str
# Region
# East       1031
# North      1019
# Central    1010
# South       986
# West        955
# south         2
# Name: count, dtype: int64

# %% [markdown]
# # ->Calculate Sales By Region

# %%
region_sales = (
    df.groupby("Region")["Revenue"]
      .sum()
      .sort_values(ascending=False)
)

print(region_sales)
# Out:
# Region
# Central    2593506.04
# North      2579432.59
# East       2577331.97
# South      2405357.52
# West       2330531.74
# south         4801.55
# Name: Revenue, dtype: float64

# %% [markdown]
# # ->Calculate profit by region.

# %%
region_profit = (
    df.groupby("Region")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print(region_profit)
# Out:
# Region
# East       569637.46
# Central    551129.88
# North      550165.16
# South      518062.49
# West       506700.04
# south         747.08
# Name: Profit, dtype: float64

# %% [markdown]
# # ->Calculate quantity sold by region.

# %%
region_quantity = (
    df.groupby("Region")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

print(region_quantity)
# Out:
# Region
# East       1902
# North      1862
# Central    1820
# South      1759
# West       1687
# south         4
# Name: Quantity, dtype: int64

# %% [markdown]
# # ->Calculate the number of orders by region.

# %%
region_orders = (
    df.groupby("Region")["Order ID"]
      .nunique()
      .sort_values(ascending=False)
)

print(region_orders)
# Out:
# Region
# East       1029
# North      1017
# Central    1008
# South       985
# West        954
# south         2
# Name: Order ID, dtype: int64

# %% [markdown]
# # ->Calculate unique customers by region.

# %%
region_customers = (
    df.groupby("Region")["Customer ID"]
      .nunique()
      .sort_values(ascending=False)
)

print(region_customers)
# Out:
# Region
# North      693
# East       687
# Central    683
# West       664
# South      661
# south        2
# Name: Customer ID, dtype: int64

# %% [markdown]
# # ->Complete Regional Analysis Table

# %%
region_analysis = df.groupby("Region").agg(
    Total_Sales=("Revenue", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Total_Orders=("Order ID", "nunique"),
    Unique_Customers=("Customer ID", "nunique")
)

print(region_analysis)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# Central   2593506.04     551129.88            1820          1008
# East      2577331.97     569637.46            1902          1029
# North     2579432.59     550165.16            1862          1017
# South     2405357.52     518062.49            1759           985
# West      2330531.74     506700.04            1687           954
# south        4801.55        747.08               4             2
#
#          Unique_Customers
# Region
# Central               683
# East                  687
# North                 693
# South                 661
# West                  664
# south                   2

# %% [markdown]
# # ->Regional Profit Margin

# %%
region_analysis["Profit_Margin"] = (
    region_analysis["Total_Profit"] /
    region_analysis["Total_Sales"]
) * 100
print(region_analysis)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# Central   2593506.04     551129.88            1820          1008
# East      2577331.97     569637.46            1902          1029
# North     2579432.59     550165.16            1862          1017
# South     2405357.52     518062.49            1759           985
# West      2330531.74     506700.04            1687           954
# south        4801.55        747.08               4             2
#
#          Unique_Customers  Profit_Margin
# Region
# Central               683      21.250380
# East                  687      22.101827
# North                 693      21.328922
# South                 661      21.537858
# West                  664      21.741821
# south                   2      15.559142

# %% [markdown]
# # ->Finding the best region.

# %%
print(
    region_analysis.sort_values(
        "Total_Sales",
        ascending=False
    )
)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# Central   2593506.04     551129.88            1820          1008
# North     2579432.59     550165.16            1862          1017
# East      2577331.97     569637.46            1902          1029
# South     2405357.52     518062.49            1759           985
# West      2330531.74     506700.04            1687           954
# south        4801.55        747.08               4             2
#
#          Unique_Customers  Profit_Margin
# Region
# Central               683      21.250380
# North                 693      21.328922
# East                  687      22.101827
# South                 661      21.537858
# West                  664      21.741821
# south                   2      15.559142

# %%
print(
    region_analysis.sort_values(
        "Total_Profit",
        ascending=False
    )
)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# East      2577331.97     569637.46            1902          1029
# Central   2593506.04     551129.88            1820          1008
# North     2579432.59     550165.16            1862          1017
# South     2405357.52     518062.49            1759           985
# West      2330531.74     506700.04            1687           954
# south        4801.55        747.08               4             2
#
#          Unique_Customers  Profit_Margin
# Region
# East                  687      22.101827
# Central               683      21.250380
# North                 693      21.328922
# South                 661      21.537858
# West                  664      21.741821
# south                   2      15.559142

# %%
print(
    region_analysis.sort_values(
        "Profit_Margin",
        ascending=False
    )
)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# East      2577331.97     569637.46            1902          1029
# West      2330531.74     506700.04            1687           954
# South     2405357.52     518062.49            1759           985
# North     2579432.59     550165.16            1862          1017
# Central   2593506.04     551129.88            1820          1008
# south        4801.55        747.08               4             2
#
#          Unique_Customers  Profit_Margin
# Region
# East                  687      22.101827
# West                  664      21.741821
# South                 661      21.537858
# North                 693      21.328922
# Central               683      21.250380
# south                   2      15.559142

# %% [markdown]
# # ->Average Order Value by Region

# %%
region_analysis["Average_Order_Value"] = (
    region_analysis["Total_Sales"] /
    region_analysis["Total_Orders"]
)
print(region_analysis)
# Out:
#          Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# Central   2593506.04     551129.88            1820          1008
# East      2577331.97     569637.46            1902          1029
# North     2579432.59     550165.16            1862          1017
# South     2405357.52     518062.49            1759           985
# West      2330531.74     506700.04            1687           954
# south        4801.55        747.08               4             2
#
#          Unique_Customers  Profit_Margin  Average_Order_Value
# Region
# Central               683      21.250380          2572.922659
# East                  687      22.101827          2504.695792
# North                 693      21.328922          2536.315231
# South                 661      21.537858          2441.987330
# West                  664      21.741821          2442.905388
# south                   2      15.559142          2400.775000

# %% [markdown]
# # ->Regional sales chat

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.bar(
    region_analysis.index,
    region_analysis["Total_Sales"]
)

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.tight_layout()
plt.show()

# %% [markdown]
# # ->Regional Profit Chart

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    region_analysis.index,
    region_analysis["Total_Profit"]
)

plt.title("Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")

plt.tight_layout()
plt.show()

# %% [markdown]
# # ->Comparing Sales vs Profit

# %%
region_analysis[
    ["Total_Sales", "Total_Profit"]
].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Sales vs Profit by Region")
plt.xlabel("Region")
plt.ylabel("Amount")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ->Finding the strongest region.

# %%
best_sales_region = region_analysis[
    "Total_Sales"
].idxmax()

print("Best Sales Region:", best_sales_region)

best_profit_region = region_analysis[
    "Total_Profit"
].idxmax()

print("Best Profit Region:", best_profit_region)

best_margin_region = region_analysis[
    "Profit_Margin"
].idxmax()

print("Best Profit Margin Region:", best_margin_region)
# Out:
# Best Sales Region: Central
# Best Profit Region: East
# Best Profit Margin Region: East

# %% [markdown]
# # ->Finding regions that need attention

# %%
average_regional_sales = region_analysis["Total_Sales"].mean()

low_sales_regions = region_analysis[
    region_analysis["Total_Sales"] < average_regional_sales
]

print(low_sales_regions)
# Out:
#         Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# south       4801.55        747.08               4             2
#
#         Unique_Customers  Profit_Margin  Average_Order_Value
# Region
# south                  2      15.559142             2400.775

# %%
average_regional_profit = region_analysis["Total_Profit"].mean()

low_profit_regions = region_analysis[
    region_analysis["Total_Profit"] < average_regional_profit
]

print(low_profit_regions)
# Out:
#         Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Region
# south       4801.55        747.08               4             2
#
#         Unique_Customers  Profit_Margin  Average_Order_Value
# Region
# south                  2      15.559142             2400.775

# %%
region_analysis.to_csv(
    "region_analysis.csv"
)

# %% [markdown]
# ## Customer Analysis ##
# 👥 Most valuable customers
# 💰 Highest-spending customers
# 📦 Customers with the most orders
# 📈 Customers generating the most profit
# 🔄 Repeat vs one-time customers
# 💵 Average Order Value (AOV)
# ⭐ Customer segments

# %% [markdown]
# # ->Customer spending calculation

# %%
customer_sales = (
    df.groupby("Customer ID")["Revenue"]
      .sum()
      .sort_values(ascending=False)
)

print(customer_sales.head(10))
# Out:
# Customer ID
# CUST1345    66963.45
# CUST1940    51586.11
# CUST1368    42349.03
# CUST1314    38677.15
# CUST1388    37662.23
# CUST2076    37586.11
# CUST1934    37113.80
# CUST1568    36220.48
# CUST2059    35124.79
# CUST1850    34627.03
# Name: Revenue, dtype: float64

# %% [markdown]
# # ->Calculating Number of orders per customer

# %%
customer_orders = (
    df.groupby("Customer ID")["Order ID"]
      .nunique()
      .sort_values(ascending=False)
)

print(customer_orders.head(10))

# %% [markdown]
# # ->Total quantity purchased by the customers

# %%
customer_quantity = (
    df.groupby("Customer ID")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

print(customer_quantity.head(10))
# Out:
# Customer ID
# CUST1345    33
# CUST1985    25
# CUST1640    24
# CUST1314    23
# CUST1221    23
# CUST1575    22
# CUST1850    21
# CUST1796    21
# CUST1934    21
# CUST1940    21
# Name: Quantity, dtype: int64

# %% [markdown]
# # ->Customer Profit

# %%
customer_profit = (
    df.groupby("Customer ID")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

print(customer_profit.head(10))
# Out:
# Customer ID
# CUST1940    12652.49
# CUST1345    11345.64
# CUST1368     8681.01
# CUST1314     8196.93
# CUST1420     8036.31
# CUST1850     7936.96
# CUST1388     7922.83
# CUST1934     7809.46
# CUST1568     7739.30
# CUST2059     7248.43
# Name: Profit, dtype: float64

# %% [markdown]
# # ->Complete Customer Analysis Table

# %%
customer_analysis = df.groupby("Customer ID").agg(
    Total_Sales=("Revenue", "sum"),
    Total_Profit=("Profit", "sum"),
    Total_Quantity=("Quantity", "sum"),
    Total_Orders=("Order ID", "nunique")
)

print(customer_analysis.head())
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders
# Customer ID
# CUST1001         9289.91       1835.71               5             4
# CUST1002         6436.66       1491.26               7             5
# CUST1003        25008.77       4855.44              12             9
# CUST1004         9026.36       1823.69              11             6
# CUST1005         9130.53       2275.23               4             3

# %% [markdown]
# # ->Average Order Value

# %%
customer_analysis["Average_Order_Value"] = (
    customer_analysis["Total_Sales"] /
    customer_analysis["Total_Orders"]
)
print(customer_analysis.head(10))
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1001         9289.91       1835.71               5             4
# CUST1002         6436.66       1491.26               7             5
# CUST1003        25008.77       4855.44              12             9
# CUST1004         9026.36       1823.69              11             6
# CUST1005         9130.53       2275.23               4             3
# CUST1006        20871.97       3912.17              14             6
# CUST1007         1876.05        472.00               4             1
# CUST1008        13527.52       2156.48               6             3
# CUST1009        15552.66       2766.99               7             4
# CUST1010        18166.67       3891.21              17             8
#
#              Average_Order_Value
# Customer ID
# CUST1001             2322.477500
# CUST1002             1287.332000
# CUST1003             2778.752222
# CUST1004             1504.393333
# ...

# %% [markdown]
# # ->Customer Profit Margin Calculation

# %%
customer_analysis["Profit_Margin"] = (
    customer_analysis["Total_Profit"] /
    customer_analysis["Total_Sales"]
) * 100
print(customer_analysis.head(10))
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1001         9289.91       1835.71               5             4
# CUST1002         6436.66       1491.26               7             5
# CUST1003        25008.77       4855.44              12             9
# CUST1004         9026.36       1823.69              11             6
# CUST1005         9130.53       2275.23               4             3
# CUST1006        20871.97       3912.17              14             6
# CUST1007         1876.05        472.00               4             1
# CUST1008        13527.52       2156.48               6             3
# CUST1009        15552.66       2766.99               7             4
# CUST1010        18166.67       3891.21              17             8
#
#              Average_Order_Value  Profit_Margin
# Customer ID
# CUST1001             2322.477500      19.760256
# CUST1002             1287.332000      23.168227
# ...

# %% [markdown]
# # ->Top 10 Customers by Revenue

# %%
top_customers_sales = customer_analysis.sort_values(
    "Total_Sales",
    ascending=False
).head(10)

print(top_customers_sales)
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1345        66963.45      11345.64              33            12
# CUST1940        51586.11      12652.49              21             9
# CUST1368        42349.03       8681.01              16             8
# CUST1314        38677.15       8196.93              23             8
# CUST1388        37662.23       7922.83              15             8
# CUST2076        37586.11       6985.51              17            11
# CUST1934        37113.80       7809.46              21            11
# CUST1568        36220.48       7739.30              14             7
# CUST2059        35124.79       7248.43              16             6
# CUST1850        34627.03       7936.96              21            10
#
#              Average_Order_Value  Profit_Margin
# Customer ID
# CUST1345             5580.287500      16.943034
# CUST1940             5731.790000      24.526932
# ...

# %% [markdown]
# # ->Top 10 customers by profit

# %%
top_customers_profit = customer_analysis.sort_values(
    "Total_Profit",
    ascending=False
).head(10)

print(top_customers_profit)
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1940        51586.11      12652.49              21             9
# CUST1345        66963.45      11345.64              33            12
# CUST1368        42349.03       8681.01              16             8
# CUST1314        38677.15       8196.93              23             8
# CUST1420        33848.96       8036.31              19             9
# CUST1850        34627.03       7936.96              21            10
# CUST1388        37662.23       7922.83              15             8
# CUST1934        37113.80       7809.46              21            11
# CUST1568        36220.48       7739.30              14             7
# CUST2059        35124.79       7248.43              16             6
#
#              Average_Order_Value  Profit_Margin
# Customer ID
# CUST1940             5731.790000      24.526932
# CUST1345             5580.287500      16.943034
# ...

# %% [markdown]
# # ->Shop customers by number of orders.

# %%
top_customers_orders = customer_analysis.sort_values(
    "Total_Orders",
    ascending=False
).head(10)

print(top_customers_orders)
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1985        33159.03       6273.02              25            12
# CUST1702        18209.03       4374.25              14            12
# CUST1345        66963.45      11345.64              33            12
# CUST1934        37113.80       7809.46              21            11
# CUST1344        29571.58       6738.68              20            11
# CUST1390        31040.33       4803.19              21            11
# CUST2076        37586.11       6985.51              17            11
# CUST1796        29433.36       5301.81              21            11
# CUST1221        34387.23       7103.41              23            11
# CUST2148        24124.31       5361.14              16            10
#
#              Average_Order_Value  Profit_Margin
# Customer ID
# CUST1985             2763.252500      18.917984
# CUST1702             1517.419167      24.022422
# ...

# %% [markdown]
# # ->Identifying Repeated Customers

# %%
repeat_customers = customer_analysis[
    customer_analysis["Total_Orders"] > 1
]

print("Repeat Customers:", len(repeat_customers))
one_time_customers = customer_analysis[
    customer_analysis["Total_Orders"] == 1
]

print("One-Time Customers:", len(one_time_customers))
# Out:
# Repeat Customers: 1104
# One-Time Customers: 81

# %% [markdown]
# # ->Identifying high-value customers

# %%
sales_median = customer_analysis["Total_Sales"].median()
profit_median = customer_analysis["Total_Profit"].median()
high_value_customers = customer_analysis[
    (customer_analysis["Total_Sales"] > sales_median) &
    (customer_analysis["Total_Profit"] > profit_median)
]

print(
    high_value_customers.sort_values(
        "Total_Profit",
        ascending=False
    ).head(10)
)
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1940        51586.11      12652.49              21             9
# CUST1345        66963.45      11345.64              33            12
# CUST1368        42349.03       8681.01              16             8
# CUST1314        38677.15       8196.93              23             8
# CUST1420        33848.96       8036.31              19             9
# CUST1850        34627.03       7936.96              21            10
# CUST1388        37662.23       7922.83              15             8
# CUST1934        37113.80       7809.46              21            11
# CUST1568        36220.48       7739.30              14             7
# CUST2059        35124.79       7248.43              16             6
#
#              Average_Order_Value  Profit_Margin
# Customer ID
# CUST1940             5731.790000      24.526932
# CUST1345             5580.287500      16.943034
# ...

# %% [markdown]
# # ->Customer Segmentation

# %%
sales_25 = customer_analysis["Total_Sales"].quantile(0.25)
sales_50 = customer_analysis["Total_Sales"].quantile(0.50)
sales_75 = customer_analysis["Total_Sales"].quantile(0.75)
def customer_segment(sales):
    if sales >= sales_75:
        return "High Value"
    elif sales >= sales_50:
        return "Medium Value"
    elif sales >= sales_25:
        return "Low Value"
    else:
        return "Very Low Value"
customer_analysis["Customer_Segment"] = (
    customer_analysis["Total_Sales"]
    .apply(customer_segment)
)
print(customer_analysis.head(10))
segment_counts = (
    customer_analysis["Customer_Segment"]
    .value_counts()
)

print(segment_counts)
segment_analysis = customer_analysis.groupby(
    "Customer_Segment"
).agg(
    Customers=("Total_Sales", "count"),
    Total_Sales=("Total_Sales", "sum"),
    Total_Profit=("Total_Profit", "sum"),
    Total_Orders=("Total_Orders", "sum")
)

print(segment_analysis)
# Out:
#              Total_Sales  Total_Profit  Total_Quantity  Total_Orders  \
# Customer ID
# CUST1001         9289.91       1835.71               5             4
# CUST1002         6436.66       1491.26               7             5
# CUST1003        25008.77       4855.44              12             9
# CUST1004         9026.36       1823.69              11             6
# CUST1005         9130.53       2275.23               4             3
# CUST1006        20871.97       3912.17              14             6
# CUST1007         1876.05        472.00               4             1
# CUST1008        13527.52       2156.48               6             3
# CUST1009        15552.66       2766.99               7             4
# CUST1010        18166.67       3891.21              17             8
#
#              Average_Order_Value  Profit_Margin Customer_Segment
# Customer ID
# CUST1001             2322.477500      19.760256     Medium Value
# ...

# %% [markdown]
# # ->Customer Segmentation Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.bar(
    segment_analysis.index,
    segment_analysis["Total_Sales"]
)

plt.title("Revenue by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Sales")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ->Top 10 Customer Visualization

# %%
top10 = customer_analysis.sort_values(
    "Total_Sales",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

plt.bar(
    top10.index.astype(str),
    top10["Total_Sales"]
)

plt.title("Top 10 Customers by Revenue")
plt.xlabel("Customer ID")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ->Repeat versus one-time customer chat

# %%
plt.figure(figsize=(7, 5))

plt.bar(
    ["One-Time", "Repeat"],
    [
        len(one_time_customers),
        len(repeat_customers)
    ]
)

plt.title("Repeat vs One-Time Customers")
plt.xlabel("Customer Type")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# #->Finding the most valuable customer

# %%
best_customer = customer_analysis[
    "Total_Sales"
].idxmax()

print("Highest Spending Customer:", best_customer)
print(
    customer_analysis.loc[
        best_customer
    ]
)
# Out:
# Highest Spending Customer: CUST1345
# Total_Sales              66963.45
# Total_Profit             11345.64
# Total_Quantity                 33
# Total_Orders                   12
# Average_Order_Value     5580.2875
# Profit_Margin           16.943034
# Customer_Segment       High Value
# Name: CUST1345, dtype: object

# %%
customer_analysis.to_csv(
    "customer_analysis.csv"
)

segment_analysis.to_csv(
    "customer_segment_analysis.csv"
)

# %% [markdown]
# ## SQLite ##

# %%
import sqlite3

print(sqlite3.sqlite_version)
import pandas as pd
import sqlite3
# Out:
# 3.50.4

# %%
df = pd.read_csv("../data/cleaned/ecommerce_sales_cleaned.csv")

# %%
df.head()
# Out:
#     Order ID  Order Date Customer ID        Category                Product  \
# 0  ORD100001  2025-03-29    CUST2124  Home & Kitchen  Storage Container Set
# 1  ORD100002  2025-01-22    CUST1253           Books   Data Analytics Guide
# 2  ORD100003  2025-09-01    CUST1832  Home & Kitchen          Non-Stick Pan
# 3  ORD100004  2025-09-22    CUST1565     Electronics      Bluetooth Speaker
# 4  ORD100005  2025-02-23    CUST2130     Electronics             Power Bank
#
#   Region     Channel    Payment Method  Quantity  Unit Price  Discount  \
# 0   East     Website  Cash on Delivery         1      949.29      0.10
# 1   West     Website       Credit Card         1      701.57      0.05
# 2  North     Website        Debit Card         5     1229.57      0.00
# 3  South  Mobile App       Credit Card         4     1966.53      0.15
# 4   West     Website  Cash on Delivery         3      933.74      0.05
#
#    Revenue   Profit
# 0   854.36   151.29
# 1   666.49   164.55
# ...

# %%
print(df.columns.tolist())
# Out:
# ['order_id', 'order_date', 'customer_id', 'customer_name', 'product', 'category', 'region', 'quantity', 'unit_price', 'sales', 'discount', 'profit', 'channel']

# %%
df.columns = [
    'order_id',
    'order_date',
    'customer_id',
    'customer_name',
    'product',
    'category',
    'region',
    'quantity',
    'unit_price',
    'sales',
    'discount',
    'profit',
    'channel'
]
conn = sqlite3.connect("ecommerce.db")
print("Database connected successfully")
# Out:
# Database connected successfully

# %%
df.to_sql(
    "sales",
    conn,
    if_exists="replace",
    index=False
)
query = """
SELECT name
FROM sqlite_master
WHERE type='table';
"""

pd.read_sql_query(query, conn)
# Out:
#     name
# 0  sales

# %%
query = """
SELECT *
FROM sales
LIMIT 10;
"""
result = pd.read_sql_query(query, conn)

result
# Out:
#     order_id  order_date customer_id   customer_name                product  \
# 0  ORD100001  2025-03-29    CUST2124  Home & Kitchen  Storage Container Set
# 1  ORD100002  2025-01-22    CUST1253           Books   Data Analytics Guide
# 2  ORD100003  2025-09-01    CUST1832  Home & Kitchen          Non-Stick Pan
# 3  ORD100004  2025-09-22    CUST1565     Electronics      Bluetooth Speaker
# 4  ORD100005  2025-02-23    CUST2130     Electronics             Power Bank
# 5  ORD100006  2025-09-28    CUST1456          Beauty            Moisturizer
# 6  ORD100007  2025-06-06    CUST1015  Home & Kitchen        Electric Kettle
# 7  ORD100008  2025-06-12    CUST1419          Beauty                Shampoo
# 8  ORD100009  2025-08-04    CUST1805         Fashion          Running Shoes
# 9  ORD100010  2025-08-06    CUST1503         Fashion           Casual Shirt
#
#   category      region          quantity  unit_price    sales  discount  \
# ...

# %% [markdown]
# # ->SQL analysis

# %%
#->Query 1=Total Sales
query = """
SELECT SUM(sales) AS total_sales
FROM sales;
"""
pd.read_sql_query(query, conn)


# ->Query 2: Total Profit 
query = """
SELECT SUM(profit) AS total_profit
FROM sales;
"""
pd.read_sql_query(query, conn)

# ->Query 3: Total orders 
query = """
SELECT COUNT(DISTINCT order_id) AS total_orders
FROM sales;
"""
pd.read_sql_query(query, conn)

# ->Query 4: Total quantity sold 
query = """
SELECT SUM(quantity) AS total_quantity
FROM sales;
"""
pd.read_sql_query(query, conn)

# ->Query 5: Average Order Value 
query = """
SELECT 
    SUM(sales) / COUNT(DISTINCT order_id) AS average_order_value
FROM sales;
"""
pd.read_sql_query(query, conn)

# ->Query 6:Sales by category 
query = """
SELECT
    category,
    SUM(sales) AS total_sales
FROM sales
GROUP BY category
ORDER BY total_sales DESC;
"""
pd.read_sql_query(query, conn)

#->Query 7: Profit by Category 
query = """
SELECT
    category,
    SUM(profit) AS total_profit
FROM sales
GROUP BY category
ORDER BY total_profit DESC;
"""
pd.read_sql_query(query, conn)

# ->Query 8: sales by region 
query = """
SELECT
    region,
    SUM(sales) AS total_sales
FROM sales
GROUP BY region
ORDER BY total_sales DESC;
"""
pd.read_sql_query(query, conn)

# ->Query 9: Profit by Region 
query = """
SELECT
    region,
    SUM(profit) AS total_profit
FROM sales
GROUP BY region
ORDER BY total_profit DESC;
"""
pd.read_sql_query(query, conn)

# ->Query 10: Top 10 Products by Sales 
query = """
SELECT
    product,
    SUM(sales) AS total_sales
FROM sales
GROUP BY product
ORDER BY total_sales DESC
LIMIT 10;
"""
pd.read_sql_query(query, conn)

# ->Query 11: column top 10 products by profit 
query = """
SELECT
    product,
    SUM(profit) AS total_profit
FROM sales
GROUP BY product
ORDER BY total_profit DESC
LIMIT 10;
"""

pd.read_sql_query(query, conn)

# ->Query 12: Top 10 customers by spending 
query = """
SELECT
    customer_id,
    SUM(sales) AS total_spending
FROM sales
GROUP BY customer_id
ORDER BY total_spending DESC
LIMIT 10;
"""
pd.read_sql_query(query, conn)

# %%
# ->Query 13: Volume Customer Purchase Frequency 
query = """
SELECT
    customer_id,
    COUNT(DISTINCT order_id) AS total_orders
FROM sales
GROUP BY customer_id
ORDER BY total_orders DESC
LIMIT 10;
"""

pd.read_sql_query(query, conn)
# Out:
#   customer_id  total_orders
# 0    CUST1985            12
# 1    CUST1702            12
# 2    CUST1345            12
# 3    CUST2076            11
# 4    CUST1934            11
# 5    CUST1796            11
# 6    CUST1390            11
# 7    CUST1344            11
# 8    CUST1221            11
# 9    CUST2148            10

# %%
# ->Query 14: Monthly Sales 
query = """
SELECT
    strftime('%Y-%m', order_date) AS month,
    SUM(sales) AS total_sales
FROM sales
GROUP BY month
ORDER BY month;
"""

pd.read_sql_query(query, conn)
# Out:
#       month  total_sales
# 0   2025-01    616651.99
# 1   2025-02    535260.12
# 2   2025-03    637099.86
# 3   2025-04    695728.13
# 4   2025-05    625735.84
# 5   2025-06    666718.69
# 6   2025-07    591153.73
# 7   2025-08    729847.64
# 8   2025-09    691995.17
# 9   2025-10    620497.39
# 10  2025-11    604048.80
# 11  2025-12    642764.71

# %%
# ->Query 15: Monthly Profit 
query = """
SELECT
    strftime('%Y-%m', order_date) AS month,
    SUM(profit) AS total_profit
FROM sales
GROUP BY month
ORDER BY month;
"""

pd.read_sql_query(query, conn)
# Out:
#       month  total_profit
# 0   2025-01     972862.40
# 1   2025-02     850470.26
# 2   2025-03    1027448.49
# 3   2025-04    1154412.29
# 4   2025-05     997602.31
# 5   2025-06    1162584.46
# 6   2025-07     997524.12
# 7   2025-08    1226068.61
# 8   2025-09    1108690.31
# 9   2025-10     937393.02
# 10  2025-11     962578.53
# 11  2025-12    1071843.07

# %%
# ->Query 16: Discount vs Profit 
query = """
SELECT
    discount,
    SUM(sales) AS total_sales,
    SUM(profit) AS total_profit
FROM sales
GROUP BY discount
ORDER BY discount;
"""

pd.read_sql_query(query, conn)
# Out:
#    discount  total_sales  total_profit
# 0      0.00   1650460.05    2968714.21
# 1      0.05   1529514.13    2633859.88
# 2      0.10   1940464.49    3091876.57
# 3      0.15   1442812.69    2216227.57
# 4      0.20    689708.66     992771.81
# 5      0.25    404542.05     566027.83

# %%
# ->Query 17: High Discount Orders 
query = """
SELECT
    order_id,
    product,
    sales,
    discount,
    profit
FROM sales
WHERE discount >=0.20
ORDER BY discount DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#       order_id               product    sales  discount   profit
# 0    ORD100007       Electric Kettle  1626.74      0.25  2440.11
# 1    ORD100022     Bluetooth Speaker  1780.44      0.25  1335.33
# 2    ORD100041   Business Management   480.97      0.25   360.73
# 3    ORD100044  Data Analytics Guide   686.81      0.25   515.11
# 4    ORD100047        Cotton T-Shirt   660.36      0.25  1485.81
# ..         ...                   ...      ...       ...      ...
# 735  ORD104962          Casual Shirt  1190.20      0.20   952.16
# 736  ORD104963          Casual Shirt  1255.03      0.20  3012.07
# 737  ORD104971             Face Wash   384.11      0.20   307.29
# 738  ORD104980           Moisturizer   580.05      0.20   928.08
# 739  ORD104997         Fiction Novel   433.81      0.20   347.05
#
# [740 rows x 5 columns]

# %%
# ->Query 18:Category + region analysis 
query = """
SELECT
    category,
    region,
    SUM(sales) AS total_sales,
    SUM(profit) AS total_profit
FROM sales
GROUP BY category, region
ORDER BY total_sales DESC;
"""

pd.read_sql_query(query, conn)
# Out:
#    category       region  total_sales  total_profit
# 0     North      Website    763773.48    1224289.34
# 1   Central      Website    743337.28    1190981.86
# 2      East      Website    708706.68    1149688.91
# 3      West      Website    686728.78    1098362.29
# 4     South      Website    634227.81    1081119.85
# 5     South   Mobile App    568887.08     899486.52
# 6      East   Mobile App    561070.68     893964.38
# 7     North   Mobile App    542870.15     932980.13
# 8      West   Mobile App    528273.80     806294.11
# 9   Central   Mobile App    507681.66     858328.81
# 10  Central  Marketplace    320908.47     539200.18
# 11     East  Marketplace    294055.89     521788.17
# 12    South  Marketplace    290047.96     416390.04
# 13    North  Marketplace    247111.00     414308.45
# 14     West  Marketplace    245148.31     416405.50
# 15    South      website      5204.25       5204.25
# 16  Unknown  Marketplace      3825.08       9477.00
# ...

# %%
# ->Query 19: Best Profitable Category-Region Combination 
query = """
SELECT
    category,
    region,
    SUM(profit) AS total_profit
FROM sales
GROUP BY category, region
ORDER BY total_profit DESC
LIMIT 10;
"""

pd.read_sql_query(query, conn)
# Out:
#   category      region  total_profit
# 0    North     Website    1224289.34
# 1  Central     Website    1190981.86
# 2     East     Website    1149688.91
# 3     West     Website    1098362.29
# 4    South     Website    1081119.85
# 5    North  Mobile App     932980.13
# 6    South  Mobile App     899486.52
# 7     East  Mobile App     893964.38
# 8  Central  Mobile App     858328.81
# 9     West  Mobile App     806294.11

# %%
def run_sql(query):
    return pd.read_sql_query(query, conn)

# %%
run_sql("""
SELECT category, SUM(sales) AS total_sales
FROM sales
GROUP BY category
ORDER BY total_sales DESC;
""")
# Out:
#   category  total_sales
# 0  Central   1571927.41
# 1     East   1564482.40
# 2    North   1553754.63
# 3    South   1498367.10
# 4     West   1460150.89
# 5  Unknown      6133.40
# 6    south      2686.24

# %% [markdown]
# ## Visualisation
